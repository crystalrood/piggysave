# %%
from bs4 import BeautifulSoup
import requests
import sys;
#reload(sys);
#sys.setdefaultencoding("utf8")
import re
import pandas as pd
import pprint
import numpy as np
import csv, sys
import base64
import datefinder
import datetime

import pymongo
from pymongo import MongoClient
import quopri
#uri = 'mongodb://heroku_4jtg3rvf:r9nq5ealpnfrlda5la4fj8r192@ds161503.mlab.com:61503/heroku_4jtg3rvf'
#client = MongoClient(uri)
#db = client['heroku_4jtg3rvf']

client = MongoClient('mongodb://localhost:27017/test')
db = client.test
import email

# %%
messages = db.messages
messages = pd.DataFrame(list(messages.find()))
    
# all this code below is to remove duplicates
del messages['_id']
del messages['createdAt']
del messages['date_extracted']
del messages['__v']
del messages['updatedAt']
del messages['status']
messages = messages.drop_duplicates()

#setting up dataframe for scrapting
columns = ['thread_id','email', 'retailer', 'date', 'order_num', 'zipcode', 'url', 'item_num', 'quantity', 'color', 'price']
#setting up dataframe
df_items = pd.DataFrame(columns=columns)

# %%
messages
# Out:
#                         email  \
# 0  crystal.wesnoski@gmail.com
#
#                                      encoded_message         thread_id
# 0  RGVsaXZlcmVkLVRvOiBjcnlzdGFsLndlc25vc2tpQGdtYW...  1609327945aa3a76

# %%
messages = db.messages
messages = pd.DataFrame(list(messages.find()))


# ###if there are actually messages in the DB, then go ahead and proceed
if len(messages) > 0:
    
    # all this code below is to remove duplicates
    del messages['_id']
    del messages['createdAt']
    del messages['date_extracted']
    del messages['__v']
    del messages['updatedAt']
    del messages['status']
    messages = messages.drop_duplicates()

    # ###only filter on emails that need to be scraped
    #messages = messages[(messages.status == 'need to scrape')]

    #setting up dataframe for scrapting
    columns = ['thread_id','email', 'retailer', 'date', 'order_num', 'zipcode', 'url', 'item_num', 'quantity', 'color', 'price']
    #setting up dataframe
    df_items = pd.DataFrame(columns=columns)

    for index, row in messages.iterrows():

        # ###decodes message and splits into lines
        msg_decoded = quopri.decodestring(base64.urlsafe_b64decode(row['encoded_message'].encode('utf8', 'replace')))
        msg_decoded = msg_decoded.decode('ISO-8859-1')
        string = msg_decoded.split('\r\n')

        # ###EMAIL of user
        email = row['email']


        # ###DATE email was sent
        recieved = 'received'
        for idx, text in enumerate(string):
            if recieved in text.lower():
                break;
        
        matches = datefinder.find_dates(string[idx+1])
        for match in matches:
            date = match.strftime('%m/%d/%Y')


        # ###RETAILER of order
        retailers = ['nordstrom']

        # ####getting retailer information
        for num in retailers:
            for idx, text in enumerate(string):
                if num in text.lower():
                    retailer = num
                    break;
                    
        
        order_num = ['order number']

        for num in order_num:
            find = False
            for idx, text in enumerate(string):
                if num in text.lower():
                    find = True
                    text = text
                    # print(idx, text)
                    break;
            if find:
                break

        order_number = ''


        try:
            order_number = re.findall(r'\d+', text )
            order_number = order_number[0]
        except:
            order_number = 'not available'
            pass


            # ####ZIPCODE if retailer is nordstrom     
            try:
                billing = ['billing address start']
                for bill in billing:
                    find = False
                    for bill_idx, text in enumerate(string):
                        if bill in text.lower():
                            find = True
                            #print(bill_idx, text)
                            break;
                    if find:
                        break
                address = ''

                for i in range (0,40):
                    address += string[bill_idx+i] + ' '

                match = re.search(r'\b\d{5}(?:-\d{4})?\b',  address)
                zip_code = match.group(0)
                print("zipcode" + zip_code)

            except:
                address_string = 'not available'
                zip_code = 'not available'
                pass

            # ####EMAIL THREAD ID
            thread_id = row['thread_id']

            print("order number" +order_number)
            ###################################################################
            ###### GETTING ITEMS INFORMATION  #################################
            ###################################################################


            order_num = ['description:']


            # print order_num
            #getting order num
            line_number = []
            find = False
            for idx, text in enumerate(string):
                if 'description:' in text.lower():
                    find = True
                    text = text
                    line_number.append(idx)
                    description_text = ''
                    for x in range(idx, idx+200):
                        description_text += string[x]

                    # ###ITEM URL
                    soup = BeautifulSoup(description_text, "html.parser")
                    url = soup.find_all('a', href=True)[0]['href']
                    r = requests.get(url) 
                    print(r.url)


                    # ###ITEM NUMBER
                    index1 = description_text.find('\t#')
                    item_number=''
                    for x in range(index1, index1+40):
                        if description_text[x].isdigit():
                            item_number += description_text[x]
                    print(item_number)


                    # ###ITEM COLOR
                    index2 = description_text.find('Color:')
                    color=''
                    for x in range(index2, index2+100):
                        color += description_text[x]

                    soup = BeautifulSoup(color, "html.parser")
                    color_name = soup.find('span').text

                    print(color_name)

                    # ###ITEM PRICE 
                    index3 = description_text.find('Price:')
                    price=''
                    for x in range(index3, index3+100):
                        price += description_text[x]

                    soup = BeautifulSoup(price, "html.parser")
                    price_name = soup.find('span').text
                    print(price_name)

                    # ###ITEM QUANTITY
                    index4 = description_text.find('Qty:')
                    quantity=''
                    for x in range(index4, index4+100):
                        quantity += description_text[x]

                    soup = BeautifulSoup(quantity, "html.parser")
                    quantity_name = soup.find('span').text
                    print(quantity_name)

            
        #inserting fow into dataframe

        df_items.loc[len(df_items)]=[
                thread_id, 
                email, 
                retailer, 
                date, 
                order_number, 
                zip_code, 
                r.url,
                item_number,
                quantity_name,
                color_name,
                price_name
                ]
        df_items[['price']] = df_items[['price']].replace('[\$,]','',regex=True).astype(float)
        df_items = df_items[(df_items.order_num != 'not available') \
                            &(df_items.price > 0)].reset_index(drop=True)

        today = datetime.date.today()
        for index, row in df_items.iterrows():
            dic = {
               'thread_id': row['thread_id'],
               'email': row['email'],
               'retailer': row['retailer'],
               'date': row['date'],
               'order_num': row['order_num'],
               'zipcode': row['zipcode'],
               'url': row['url'],
               'item_num': row['item_num'],
               'quantity': row['quantity'],
               'color': row['color'],
               'price': row['price'],
               'last_date_checked': str(today),
               'status': 'tracking'
              }
            result = db.order_info_item_scrapes.insert_one(dic)
  
  
        #this changes the status from "need to scrape" to "scraped" in
        #the messages database
        for index, row in messages.iterrows():
            db.messages.update_many(
                {"thread_id": row['thread_id']},
                {"$set": {"status": "scraped"}}
            )


        print('testedandsuccess')


        #print df.head()
# Out:
# zipcode94085
# order numbernot available
# https://shop.nordstrom.com/s/lancome-advanced-genifique-youth-activating-trio-nordstrom-exclusive-236-50-value/4798008?cm_mmc=email_tran-_-122617-_-ship_confirm-_-proddescr1&cm_em=
#
# No Color
# $148.75
# 1
# https://shop.nordstrom.com/s/4498534?cm_mmc=email_tran-_-122617-_-ship_confirm-_-proddescr2&cm_em=
#
# No Color
# $0.00
# 1
# https://shop.nordstrom.com/s/4623993?cm_mmc=email_tran-_-122617-_-ship_confirm-_-proddescr3&cm_em=
#
# No Color
# $0.00
# 1
# testedandsuccess

# %%
df_items
# Out:
# Empty DataFrame
# Columns: [thread_id, email, retailer, date, order_num, zipcode, url, item_num, quantity, color, price]
# Index: []

# %%
df_items
# Out:
# Empty DataFrame
# Columns: [thread_id, email, retailer, date, order_num, zipcode, url, item_num, quantity, color, price]
# Index: []

# %%
 # ###decodes message and splits into lines
msg_decoded = quopri.decodestring(base64.urlsafe_b64decode(messages['encoded_message'][0].encode('utf8', 'replace')))
msg_decoded = msg_decoded.decode('ISO-8859-1')
string = msg_decoded.split('\r\n')

# %%
string
# Out:
# ['Delivered-To: crystal.wesnoski@gmail.com',
#  'Received: by 10.37.63.196 with SMTP id m187csp1905900yba;',
#  '        Tue, 26 Dec 2017 06:08:53 -0800 (PST)',
#  'X-Google-Smtp-Source: ACJfBovc5VgKRYSpIuwewXL0vlq7ssUeDecJm1npF+Crj9XGqwv7vLlAEm66Thn+1G84NhTCtiAL',
#  'X-Received: by 10.99.61.67 with SMTP id k64mr22640580pga.421.1514297333121;',
#  '        Tue, 26 Dec 2017 06:08:53 -0800 (PST)',
#  'ARC-Seal: i=1; a=rsa-sha256; t\x1514297333; cv=none;',
#  '        d=google.com; s=arc-20160816;',
#  '        b=wU8jbPiyBc+BP+HJNjCXAf4u8V+n2fjjDLSMCMNbhZrfhQXmhIPt+3SamISFnRfAy2',
#  '         XDJMalnltAPt5URwkdEilv/lyO7xfF7k01ntpAa9Dg082zdqs0jwtMIMaMfr93RJfzik',
#  '         RzS4zqDxnKGJtON89f5oYQ15QB+ON+Oz40iQSdD6ydMkF5O/jqpuqPR3yeFYRsY13STN',
#  '         kcdu+aNR+e2VjTmGgyA5Z91J83eNKLydFqqgQlOZnHGknHDtLrqvpsvAwhhnzQtmA3N8',
#  '         5e+At6WLTrQqdQG8ZOxN7mZ7v5vIQ0zppb3oPbiWDRUEl/zW7GhztYvHUQLLhXVjbJxE',
#  '         E/Pw=',
#  'ARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;',
#  '        h=message-id:feedback-id:subject:reply-to:from:to:date',
#  '         :content-transfer-encoding:mime-version:dkim-signature',
#  '         :dkim-signature:arc-authentication-results;',
#  '        bh=IGODwkT0gJZLJQRs6evN32IOl3GbMvzASHTfKj/SZkM=;',
#  '        b=vncRKTwpMHe9kYV0YFFAss8fzexc4pa5eIZACAq0bOliBiO1ZbKJP5komXhb+pgXS5',
#  '         EaeK9sCh3L3yJ/eMqNeLcLhLefDmpnNeyQt6zzjpxPGUIZ+rnk0KSDHgr9LsnjWC+quY',
#  '         DSkEZmWBtNYFWG2IBiC8PUHKtCRp169O+cRuqxB1Cy2R5hXHYsWsKHAjBKVBQ4c1WQxq',
#  '         jhC3SprCvm++faD5bPNmony9ZWQ1xp0ByvVM+P5dDfqGrDilirhhMeAqaOGFzIjaF16D',
#  '         tNkJd+CdG0J6OOXfH0ZzsFugJwTYJ+6UxcnUdmhmOjG+dWGKzzvYTB0qO5/XZ6iy1tws',
#  '         yIsA=',
#  'ARC-Authentication-Results: i=1; mx.google.com;',
#  '       dkim=pass header.i=@em.nordstrom.com header.s=nordstrom header.b=cZpqTwcy;',
#  '       dkim=pass header.i=@responsys.net header.s=oraclersys header.b=K4dPgUjX;',
#  '       spf=pass (google.com: domain of contact@em.nordstrom.com designates 199.7.203.142 as permitted sender) smtp.mailfrom=contact@em.nordstrom.com;',
#  '       dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=em.nordstrom.com',
#  'Return-Path: <contact@em.nordstrom.com>',
#  'Received: from omptrans.em.nordstrom.com (omptrans.em.nordstrom.com. [199.7.203.142])',
#  '        by mx.google.com with ESMTPS id h1si21182588plh.387.2017.12.26.06.08.52',
#  '        for <crystal.wesnoski@gmail.com>',
#  '        (version=TLS1_2 cipherìDHE-RSA-AES128-GCM-SHA256 bits\x128/128);',
#  '        Tue, 26 Dec 2017 06:08:53 -0800 (PST)',
#  'Received-SPF: pass (google.com: domain of contact@em.nordstrom.com designates 199.7.203.142 as permitted sender) client-ip\x199.7.203.142;',
#  'Authentication-Results: mx.google.com;',
#  '       dkim=pass header.i=@em.nordstrom.com header.s=nordstrom header.b=cZpqTwcy;',
#  '       dkim=pass header.i=@responsys.net header.s=oraclersys header.b=K4dPgUjX;',
#  '       spf=pass (google.com: domain of contact@em.nordstrom.com designates 199.7.203.142 as permitted sender) smtp.mailfrom=contact@em.nordstrom.com;',
#  '       dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=em.nordstrom.com',
#  'DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed; s=nordstrom; d=em.nordstrom.com;',
#  ' h=MIME-Version:Content-Type:Content-Transfer-Encoding:Date:To:From:Reply-To:',
#  ' Subject:Feedback-ID:Message-ID; i=contact@em.NORDSTROM.com;',
#  ' bh=IGODwkT0gJZLJQRs6evN32IOl3GbMvzASHTfKj/SZkM=;',
#  ' b=cZpqTwcypoXRMal5aTERJxDrJl0UYTeeDZ6Bef+/qPWIdEI3MmfmWquABFE/2lFRFlkRLkUa+Mzv',
#  '   HXsgXXcnimjxc9f6b0BhakDTRGrlfMQufNZozzvmKsaXSm5vpJCGH3YEQyJswkADHq8Kymq/UGqa',
#  '   EGmw0jLWB+dwvHK5wx4DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed; s=oraclersys; d=responsys.net;',
#  ' h=MIME-Version:Content-Type:Content-Transfer-Encoding:Date:To:From:Reply-To:',
#  ' Subject:Feedback-ID:Message-ID;',
#  ' bh=IGODwkT0gJZLJQRs6evN32IOl3GbMvzASHTfKj/SZkM=;',
#  ' b=K4dPgUjXnbH8PSrsuozVDKf4A6n3Lt2XiDAsFHmFxKD/JLWqDihnINjYXZhY4/7tMQls83cIv1Dd',
#  '   SmWsVCsmCtfxqwlmHXPn4WsgQSyHXTbBumAltmuWF16utb7KmdyQdlkH3DN2cs3qWHdYNDS9JaYP',
#  '   TxO2Kfjb4EGlMSDXg9EReceived: by omptrans.em.nordstrom.com id h89bv829qu8b for <crystal.wesnoski@gmail.com>; Tue, 26 Dec 2017 06:08:51 -0800 (envelope-from <contact@em.NORDSTROM.com>)',
#  'X-CSA-Complaints: whitelist-complaints@eco.de',
#  'MIME-Version: 1.0',
#  'Content-Type: text/html;',
#  '\tcharset="UTF-8"',
#  'Content-Transfer-Encoding: quoted-printable',
#  'Date: Tue, 26 Dec 2017 06:08:51 -0800',
#  'To: crystal.wesnoski@gmail.com',
#  'From: "NORDSTROM.COM" <contact@em.NORDSTROM.com>',
#  'Reply-To: "NORDSTROM.COM" <reply@em.nordstrom.com>',
#  'Subject: Find out when your order will arrive',
#  'Feedback-ID: 52010:22271:oraclersys',
#  'X-sgxh1: JjPklHtQOLkghkspxnuHptQJhu',
#  'X-rext: 5.interact5.ErCyyvke1TQUUOMYSbmgSUWxh48Hu32vDhDMfc9e2NzKPdUHV0',
#  'X-cid: nordstrom.35405',
#  'Message-ID: <0.1.99.50C.1D37E530E9280A6.0@omptrans.em.nordstrom.com>',
#  '',
#  '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">',
#  '<html>',
#  '<head>',
#  '    <title>NORDSTROM</title>',
#  '    <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1" />',
#  '<meta name="x-apple-disable-message-reformatting">',
#  '    <meta name="viewport" content="width=device-width">',
#  '    <link href="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/Nordstrom-b4_240.css" rel="stylesheet" type="text/css" />',
#  '    <link href="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/Transactional_ConfirmOrderShipment_400_v3.css" rel="stylesheet" type="text/css" />',
#  '    <link href="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/recommendations_v3_Prod.css" rel="stylesheet" type="text/css" />',
#  '    <!--link href="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/hnav_20160308.css" rel="stylesheet" type="text/css" /-->',
#  '    <link href="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/socialfooter_20151109.css" rel="stylesheet" type="text/css" />',
#  '\t<link href="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/promo_styles_170712_598-292.css" rel="stylesheet" type="text/css" />',
#  '</head>',
#  '<body width="100%" style="background-color:#ffffff; padding:0px; margin:0px">',
#  '<!-- Hidden RIID field for Navar scraping -->',
#  '<input type="hidden" name="RIID" value="2439564415">',
#  '<style type="text/css">',
#  '     html { -webkit-text-size-adjust:none; -ms-text-size-adjust:none;}',
#  '     body { width:100%; margin:0 auto; padding:0; }',
#  '    .ExternalClass, .ExternalClass span, .ExternalClass td, .ExternalClass div {line-height: 100%;} ',
#  '    .ExternalClass {width:100%;}',
#  '    @media all and (max-width: 640px){',
#  '    *[class].alignc {text-align:center !important;}',
#  '    *[class].height13 {height: 13px !important;}',
#  '    *[class].height16 {height: 16px !important;}',
#  '    *[class].width263 {width: 263px !important;}',
#  '    *[class].width292 {width: 292px !important;}',
#  '        @media screen and (max-width: 600px){',
#  '\t/* START NAVIGATION STYLES */ ',
#  '\t\t/* HOLIDAY HAMBURGER MENU */    ',
#  '\t\t*[class].menu {',
#  '\t\tposition: relative;',
#  "\t\tbackground-image: url('https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/holiday_logo_m_1017.gif') !important;",
#  '\t\tbackground-repeat: no-repeat;',
#  '\t\tbackground-position: top 0px left 43px;',
#  '\t\tbackground-size: 227px 35px;',
#  '\t\twidth:292px;',
#  '\t\theight:35px;',
#  '\t\tpadding: 0;',
#  '\t\tmargin-left: 20px;',
#  '\t\tz-index: 9;',
#  '\t\t}',
#  '\t\t',
#  '\t\t*[class].menu ul {',
#  '\t\tmax-height: 0;',
#  '\t\toverflow: hidden;',
#  '\t\ttransition: max-height 0.25s linear;',
#  '\t\tmargin: 11px 0 0 -20px;',
#  '\t\tpadding: 8px 0 0 0;',
#  '\t\t}',
#  '\t',
#  '\t\t*[class].menu li {',
#  '\t\tvisibility: hidden;',
#  '\t\tdisplay: block; ',
#  '\t\tborder: none;',
#  '\t\tbackground-color:#ffffff;',
#  '\t',
#  '\t\t}',
#  '\t\t',
#  '\t\t*[class].menu li { float:left; padding-left: 17px;}        ',
#  '\t\t',
#  '\t\t*[class].menu *[class].navbar-handle {',
#  '\t\tdisplay: block;',
#  '\t\tmargin-top:11px;',
#  "\t\tbackground-image: url('https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_hamburger_0717.gif') !important;",
#  '\t\tbackground-size: 21px 17px !important;',
#  '\t\tbackground-repeat: no-repeat;',
#  '\t\t}',
#  '\t\t#navbar-checkbox:checked + *[class].menu ul {',
#  '\t\tmax-height: 700px;',
#  '\t\t}',
#  '\t\t#navbar-checkbox:checked + *[class].menu li {',
#  '\t\tvisibility: visible;',
#  '\t\t}',
#  '\t\t#navbar-checkbox:checked + *[class].menu *[class].navbar-handle,',
#  '\t\t#navbar-checkbox:checked + *[class].menu *[class].navbar-handle:after,',
#  '\t\t#navbar-checkbox:checked + *[class].menu *[class].navbar-handle:before {',
#  "\t\tbackground-image: url('https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_close_0717.gif') !important; background-size: 20px 18px !important;",
#  '\t\tbackground-repeat: no-repeat;',
#  '\t\t',
#  '\t\t}',
#  '\t\t*[class].navbar-checkbox {',
#  '\t\tdisplay: none;',
#  '\t\t}',
#  '\t\t*[class].navbar-handle {',
#  '\t\tdisplay: none;',
#  '\t\tcursor: pointer;',
#  '\t\tpadding: 0;',
#  '\t\theight: 19px;',
#  '\t\twidth: 26px;',
#  '\t\tborder-top: 0; ',
#  '\t\t}',
#  '\t\t*[class].navbar-handle:before,',
#  '\t\t*[class].navbar-handle:after {',
#  '\t\tposition: absolute;',
#  "\t\tcontent: ' ';",
#  '\t\t',
#  '\t\t}',
#  '\t\t*[class].menu *[class].navbar-handle {',
#  '\t\tposition: absolute;',
#  '\t\ttop: 0;',
#  '\t\tleft: 0;',
#  '\t\tz-index: 10;',
#  '\t\t}',
#  '\t\t/* END HOLIDAY HAMBURGER MENU */  ',
#  '\t\t',
#  '\t\t/* GLOBAL NAVIGATION STYLES */',
#  '\t\t*[class].hide {display:none !important;}',
#  '    \t*[class].show {display: block !important; width: auto !important; overflow: visible !important; float: none !important; max-height: inherit !important; line-height: inherit !important;}',
#  '\t\t*[class].width370 {width:370px !important;}',
#  '\t\t*[class].width292 {width:292px !important;}',
#  '\t\t*[class].paddingt38 {padding-top:38px !important;}',
#  '\t/* END NAVIGATION STYLES */',
#  '    }    ',
#  '    </style>',
#  '<!--[if gte mso 9]>',
#  '<style type="text/css">',
#  '.padl8{margin-left:8px;}',
#  '.padl9{margin-left:9px;}',
#  '.padl10{margin-left:10px;}',
#  '.padr10{margin-right:10px;}',
#  '.mr10{margin-right:10px;}',
#  '.lhfix {mso-line-height-rule: exactly;}',
#  '.pad15 {margin-right:15px; margin-left:15px;}',
#  '.padr10padl2{margin-right:10px; margin-left:2px;}',
#  '</style>',
#  '<![endif]-->',
#  '',
#  '<!-- XSLT Init Doc -->',
#  '',
#  '\t\t\t',
#  '\t\t\t',
#  '\t\t\t',
#  '\t\t',
#  '<?xml version="1.0" encoding="UTF-8"?>',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '<center>',
#  '<table cellpadding="0" cellspacing="0" width="626" class="width320" align="center">',
#  '<tr>',
#  '    <td align="center" valign="top">',
#  '        <table cellpadding="0" cellspacing="0" width="605" class="width292">',
#  '        <tr>',
#  '            <td width="3" class="hide"></td>',
#  '            <td width="598" class="width292">',
#  '                    <!-- Start Preheader -->',
#  '                    <table cellpadding="0" cellspacing="0" width="598" class="width292">',
#  '                    <tr>',
#  '                        <td width="598" height="57" class="width292" align="center" valign="middle">',
#  '                            <div style="font-size:10px; font-family:Arial, Helvetica, sans-serif; color:#787878; line-height:12px;">',
#  '                                <a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWUUADC&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemE-d6TLwXxX4aUwhX4VpJV5xg_IC10P-hGBdAlkGZEH-Z5Pu-0hM-wbXGXpbfG7REwfra-ldZj1WVSJeO2_BTfd0J1a074Q2CR3XgNPqQE1qdfrkFrs9rJZEmd56v5TFFBG6CxPB7AAbaml5uE_M." style="color:#787878; line-height:12px; text-decoration:none;" class="block preheadermobile"><span class="block"></span></a>',
#  '                                <a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWUUADD&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemEHXpqY_w8hES_RVjIR-AMIZ39DOmASNfyhvly6surugxHsIolOBhXbGm3K9_ZML-MXascfyOjsuuF501VbCxN3s4Ztxh7BG7s2i-gJxSxsy3VER8EXoTyFZEFYlVjxKECbZIXtCentDmzpESgwJ5Ob80rQrsFLQN1UmptT2tu-wPq3w." style="color:#787878; line-height:12px; text-decoration:none;">See their expected delivery date and more.</a>',
#  '                            </div>',
#  '                        </td>',
#  '                    </tr>',
#  '                    </table>',
#  '                    <!-- End Preheader -->',
#  '                    ',
#  '                     <!--Start Header Nav-->',
#  '                    <!--document(contentlibrary/transactional/master_templates,Header_Nav_2017_Prod)-->',
#  '                <table cellpadding="0" cellspacing="0">',
#  '        <tr>',
#  '            <td width="598" align="left" valign="top" class="width292" style="padding-top: 17px;">',
#  '                <table cellpadding="0" cellspacing="0">',
#  '                <tr>',
#  '                    <td width="598" class="width292" align="left" valign="middle">',
#  '                        <div class="hide"><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURT&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemyd2hQVySOWJaZ6ICDwxDEnwBc-aQ57pEZ93yl1YN9DlV_H9T6yfYf2xPeOGb1TilEQuIWeLa2KqT71oMc1XJ-eXPwxX_8U0n6VEZZy-MvgysPSWm_XrCx-nXuhaOjWUeb45YPPOH2IU_M."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/holiday_logo_1017.gif" width="262" height="40" alt="love, NORDSTROM" border="0" style="display:block;" class="hide"/></a></div>',
#  '                    </td>',
#  '                </tr>',
#  '                </table>',
#  '                <div style="line-height:27px;" class="lhfix hide">&nbsp;</div>',
#  '',
#  '                <!-- HOLIDAY DESKTOP NAV -->',
#  '                <table cellpadding="0" cellspacing="0" width="598" class="hide">',
#  '                <tr>',
#  '                    <td valign="top" align="left">',
#  '                        <table cellpadding="0" cellspacing="0" width="598">',
#  '                        <tr>',
#  '                        \t<td width="104" align="left" valign="bottom"><div><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DBTCBSUY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemLa4j-di6HDDG_mSLuVV8Sst0F9k2qiHyyM2pAbQRz3lYsXbt2za89GxXNdHZ3oKF_uGRhCz0z0VDWz7tSDqQxZ36KdJMNar1obmdLiEgoN0Xzs11_tYf9Q7Y91c8KmbP1X6K7PQ6x1TTr8." style="color:#e1261c; font-family:Arial, Helvetica, sans-serif; font-size:11px; line-height:12px; text-decoration:none; font-weight: bold;">Holiday&nbsp;Gifts</a></div></td>',
#  '                            <td width="143" align="left" valign="bottom"><div><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DURYASDY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemKNbM2e-3qB3p8s2mRvsCvSpgBuQyixRs_FHOkH7DW1Y5HyBvNoLpPYm8do3Qho2XMnkIXuhMLCYpZIVu8UaZX76NkO6zXuHUPX2NUaJfqCUu6qJS6WcbHJAGE2Ra5xrvA43EOBl2sMKD7vDWDbz." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:11px; line-height:12px; text-decoration:none; font-weight: bold;">Designer&nbsp;Collections</a></div></td>',
#  '                            <td width="76" align="left" valign="bottom"><div><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURU&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemIt_JXruuwsMJ2U_Nt_ZmqkVa_r8BToMqDG-9Fx2vXHh9gfgTtHYcrmxVcyZxzUVYStx-4_ypu1f0_DQUkFuh52WHePghxrD0yYSMXIzOooOIFaOC7zEbgMkcjJt3Kwia9HFunncEA-Sbh4." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:11px; line-height:12px; text-decoration:none;font-weight: bold; ">Women</a></div></td>',
#  '                            <td width="57" align="left" valign="bottom"><div><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURW&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemGKLvX1fCufIhkC1aIr3MrYPL90ie7uMyMyxoMj_mcHmGkcSwSgmfPumYYHv6lCXtqxJ6u0B3KVsbkes58s9Hm5iiu6qJDtHpc8lRsZFZG6mGmigYtdyXLmFSJO9_rFy8YXsO1L_4LLz." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:11px; line-height:12px; text-decoration:none;font-weight: bold; ">Men</a></div></td>',
#  '                            <td width="59" align="left" valign="bottom"><div><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURA&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemKhdbch2jz5IDNfd1fRyKqdZk80sUCla1RL50ae8FWbgGerKu4S4gvfkMZtn75LdHlmjfn8Lk5F18TbMztp1PrftRrS90bbo6lEcYcCicVDcWR7AlYJaY4QuyvRwDwfzw-WSKix6yIvtHg." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:11px; line-height:12px; text-decoration:none;font-weight: bold; ">Kids</a></div></td>',
#  '                            <td width="66" align="left" valign="bottom"><div><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DBTCBSSY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemxwQChFwnpBbOQhGaVO4HZAywYjX0ozPPG6xro32Ue5FR482dFx1w0atjlRrX4S9Fd1tMREitJnniIFEvu6KIIYn2hGy5_YPsxQz51nAz1a9oMnZ5xVMds_QVpI8Zlg6N4a68zVwQGB7yg." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:11px; line-height:12px; text-decoration:none;font-weight: bold; ">Home</a></div></td>',
#  '                            <td width="54" align="left" valign="bottom"><div><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DURYASBY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemF3-9Cnius6MoKw0GwZrayq5NRf7heyLJQzZd-mLv49Zq-V-Tu0CsKAr9YONXT0ev1upYJkRniHYGoEg9nWe255NGG15vt7tBBcQQYTmGuJSaVHnappU2y7Ri9DV3ePJ-JcOvMfPScNJwFzy." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:11px; line-height:12px; text-decoration:none;font-weight: bold; ">Beauty</a></div></td>',
#  '                            <td width="39" align="right" valign="bottom"><div><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURC&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemHrUxxdjqluo4mV6Jvx_YKcMcf15WsRUq9mig8rvrnXOIGkVBIjhQz4PR9J9Tn_HwijLFH7A3-g_khHk6ELHt4DQB4vXENJmMLX9cZCvulEqm8L7Rx5xpONYeuhC4L_-CEkrv7W80fjAaM." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:11px; line-height:12px; text-decoration:none;font-weight: bold; ">Sale</a></div></td>',
#  '                        </tr>',
#  '                        </table>',
#  '                    </td>',
#  '                </tr>',
#  '                </table>',
#  '                <div style="line-height:7px;" class="lhfix">&nbsp;</div>',
#  '                <!-- /End HOLIDAY DESKTOP NAV -->',
#  '',
#  '                <!-- HOLIDAY MOBILE NAV WITH HAMBURGER MENU-->',
#  '                \t<!--[if !mso]><!-->',
#  '                    <div class="show" style="display:none; float:left; overflow:hidden; width:0; max-height:0; line-height:0;">',
#  '                      \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                        <tr>',
#  '                          \t<td align="left" valign="top">',
#  '                            \t<form style="border:0 !important;">',
#  '                              \t<input type="checkbox" id="navbar-checkbox" class="navbar-checkbox">',
#  '                              \t<div class="menu">',
#  '                                \t<table border="0" cellpadding="0" cellspacing="0">',
#  '                                  \t<tr>',
#  '                                    \t<td width="44"></td>',
#  '                                    \t<td width="227" height="35">',
#  '                                      \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURT&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemyd2hQVySOWJaZ6ICDwxDEnwBc-aQ57pEZ93yl1YN9DlV_H9T6yfYf2xPeOGb1TilEQuIWeLa2KqT71oMc1XJ-eXPwxX_8U0n6VEZZy-MvgysPSWm_XrCx-nXuhaOjWUeb45YPPOH2IU_M."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/spcr.gif" width="227" height="35" alt="love, NORDSTROM" border="0" style="display:block;"/></a>',
#  '                                    \t</td>',
#  '                                  \t</tr>',
#  '                                \t</table>',
#  '                                \t<ul>',
#  '                                    <li>',
#  '                                    \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                      \t<tr>',
#  '                                        \t<td width="4" bgcolor="#ffffff" style="background-color:#ffffff;"></td>',
#  '                                        \t<td width="206" height="51" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DBTCBSUY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemLa4j-di6HDDG_mSLuVV8Sst0F9k2qiHyyM2pAbQRz3lYsXbt2za89GxXNdHZ3oKF_uGRhCz0z0VDWz7tSDqQxZ36KdJMNar1obmdLiEgoN0Xzs11_tYf9Q7Y91c8KmbP1X6K7PQ6x1TTr8." style="color:#e1261c; font-family:Arial, Helvetica, sans-serif; font-size:14px; line-height:51px; text-decoration:none; font-weight: bold; width: 100%; height: 100%; display: inline-block; vertical-align: middle; letter-spacing: .3px;">Holiday&nbsp;Gifts</a>',
#  '                                        \t</td>',
#  '                                       \t\t<td width="30" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DBTCBSUY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemLa4j-di6HDDG_mSLuVV8Sst0F9k2qiHyyM2pAbQRz3lYsXbt2za89GxXNdHZ3oKF_uGRhCz0z0VDWz7tSDqQxZ36KdJMNar1obmdLiEgoN0Xzs11_tYf9Q7Y91c8KmbP1X6K7PQ6x1TTr8."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/holiday_nav_arrow_1017.gif" width="9" height="18" border="0" style="display:block;" /></a>',
#  '                                        \t</td>',
#  '                                      \t</tr>',
#  '                                    \t</table>',
#  '                                  \t</li>',
#  '                                  \t<li>',
#  '                                    \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                      \t<tr>',
#  '                                        \t<td width="4" bgcolor="#ffffff" style="background-color:#ffffff;"></td>',
#  '                                        \t<td width="206" height="51" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DURYASDY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemKNbM2e-3qB3p8s2mRvsCvSpgBuQyixRs_FHOkH7DW1Y5HyBvNoLpPYm8do3Qho2XMnkIXuhMLCYpZIVu8UaZX76NkO6zXuHUPX2NUaJfqCUu6qJS6WcbHJAGE2Ra5xrvA43EOBl2sMKD7vDWDbz." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:14px; line-height:51px; text-decoration:none; font-weight: bold; width: 100%; height: 100%; display: inline-block; vertical-align: middle; letter-spacing: .3px;">Designer&nbsp;Collections</a>',
#  '                                        \t</td>',
#  '                                       \t\t<td width="30" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DURYASDY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemKNbM2e-3qB3p8s2mRvsCvSpgBuQyixRs_FHOkH7DW1Y5HyBvNoLpPYm8do3Qho2XMnkIXuhMLCYpZIVu8UaZX76NkO6zXuHUPX2NUaJfqCUu6qJS6WcbHJAGE2Ra5xrvA43EOBl2sMKD7vDWDbz."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_arrow_0717.gif" width="9" height="18" border="0" style="display:block;" /></a>',
#  '                                        \t</td>',
#  '                                      \t</tr>',
#  '                                    \t</table>',
#  '                                  \t</li>',
#  '                                 \t<li>',
#  '                                    \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                      \t<tr>',
#  '                                        \t<td width="4" bgcolor="#ffffff" style="background-color:#ffffff;"></td>',
#  '                                        \t<td width="206" height="51" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                            \t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURU&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemIt_JXruuwsMJ2U_Nt_ZmqkVa_r8BToMqDG-9Fx2vXHh9gfgTtHYcrmxVcyZxzUVYStx-4_ypu1f0_DQUkFuh52WHePghxrD0yYSMXIzOooOIFaOC7zEbgMkcjJt3Kwia9HFunncEA-Sbh4." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:14px; line-height:51px; text-decoration:none; font-weight: bold; width: 100%; height: 100%; display: inline-block; vertical-align: middle; letter-spacing: .3px;">Women</a>',
#  '                                        \t</td>',
#  '                                        \t<td width="30" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURU&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemIt_JXruuwsMJ2U_Nt_ZmqkVa_r8BToMqDG-9Fx2vXHh9gfgTtHYcrmxVcyZxzUVYStx-4_ypu1f0_DQUkFuh52WHePghxrD0yYSMXIzOooOIFaOC7zEbgMkcjJt3Kwia9HFunncEA-Sbh4."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_arrow_0717.gif" width="9" height="18" border="0" style="display:block;" /></a>',
#  '                                        \t</td>',
#  '                                      \t</tr>',
#  '                                    \t</table>',
#  '                                  \t</li>',
#  '                                  \t<li>',
#  '                                    \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                      \t<tr>',
#  '                                        \t<td width="4" bgcolor="#ffffff" style="background-color:#ffffff;"></td>',
#  '                                        \t<td width="206" height="51" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURW&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemGKLvX1fCufIhkC1aIr3MrYPL90ie7uMyMyxoMj_mcHmGkcSwSgmfPumYYHv6lCXtqxJ6u0B3KVsbkes58s9Hm5iiu6qJDtHpc8lRsZFZG6mGmigYtdyXLmFSJO9_rFy8YXsO1L_4LLz." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:14px; line-height:51px; text-decoration:none; font-weight: bold; width: 100%; height: 100%; display: inline-block; vertical-align: middle; letter-spacing: .3px;">Men</a>',
#  '                                        \t</td>',
#  '                                        \t<td width="30" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURW&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemGKLvX1fCufIhkC1aIr3MrYPL90ie7uMyMyxoMj_mcHmGkcSwSgmfPumYYHv6lCXtqxJ6u0B3KVsbkes58s9Hm5iiu6qJDtHpc8lRsZFZG6mGmigYtdyXLmFSJO9_rFy8YXsO1L_4LLz."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_arrow_0717.gif" width="9" height="18" border="0" style="display:block;" /></a>',
#  '                                        \t</td>',
#  '                                      \t</tr>',
#  '                                    \t</table>',
#  '                                  \t</li>',
#  '                                  \t<li>',
#  '                                    \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                      \t<tr>',
#  '                                        \t<td width="4" bgcolor="#ffffff" style="background-color:#ffffff;"></td>',
#  '                                        \t<td width="206" height="51" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURA&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemKhdbch2jz5IDNfd1fRyKqdZk80sUCla1RL50ae8FWbgGerKu4S4gvfkMZtn75LdHlmjfn8Lk5F18TbMztp1PrftRrS90bbo6lEcYcCicVDcWR7AlYJaY4QuyvRwDwfzw-WSKix6yIvtHg." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:14px; line-height:51px; text-decoration:none; font-weight: bold; width: 100%; height: 100%; display: inline-block; vertical-align: middle; letter-spacing: .3px;">Kids</a>',
#  '                                        \t</td>',
#  '                                        \t<td width="30" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                         \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURA&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemKhdbch2jz5IDNfd1fRyKqdZk80sUCla1RL50ae8FWbgGerKu4S4gvfkMZtn75LdHlmjfn8Lk5F18TbMztp1PrftRrS90bbo6lEcYcCicVDcWR7AlYJaY4QuyvRwDwfzw-WSKix6yIvtHg."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_arrow_0717.gif" width="9" height="18" border="0" style="display:block;" />\t</a>',
#  '                                        \t</td>',
#  '                                      \t</tr>',
#  '                                    \t</table>',
#  '                                  \t</li>',
#  '                                  \t<li>',
#  '                                    \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                      \t<tr>',
#  '                                        \t<td width="4" bgcolor="#ffffff" style="background-color:#ffffff;"></td>',
#  '                                        \t<td width="206" height="51" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DBTCBSSY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemxwQChFwnpBbOQhGaVO4HZAywYjX0ozPPG6xro32Ue5FR482dFx1w0atjlRrX4S9Fd1tMREitJnniIFEvu6KIIYn2hGy5_YPsxQz51nAz1a9oMnZ5xVMds_QVpI8Zlg6N4a68zVwQGB7yg." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:14px; line-height:51px; text-decoration:none; font-weight: bold; width: 100%; height: 100%; display: inline-block; vertical-align: middle; letter-spacing: .3px;">Home</a>',
#  '                                       \t\t</td>',
#  '                                        \t<td width="30" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DBTCBSSY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemxwQChFwnpBbOQhGaVO4HZAywYjX0ozPPG6xro32Ue5FR482dFx1w0atjlRrX4S9Fd1tMREitJnniIFEvu6KIIYn2hGy5_YPsxQz51nAz1a9oMnZ5xVMds_QVpI8Zlg6N4a68zVwQGB7yg."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_arrow_0717.gif" width="9" height="18" border="0" style="display:block;" /></a>',
#  '                                        \t</td>',
#  '                                      \t</tr>',
#  '                                    \t</table>',
#  '                                  \t</li>',
#  '                                  \t<li>',
#  '                                    \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                      \t<tr>',
#  '                                        \t<td width="4" bgcolor="#ffffff" style="background-color:#ffffff;"></td>',
#  '                                        \t<td width="206" height="51" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DURYASBY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemF3-9Cnius6MoKw0GwZrayq5NRf7heyLJQzZd-mLv49Zq-V-Tu0CsKAr9YONXT0ev1upYJkRniHYGoEg9nWe255NGG15vt7tBBcQQYTmGuJSaVHnappU2y7Ri9DV3ePJ-JcOvMfPScNJwFzy." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:14px; line-height:51px; text-decoration:none; font-weight: bold; width: 100%; height: 100%; display: inline-block; vertical-align: middle; letter-spacing: .3px;">Beauty</a>',
#  '                                        \t</td>',
#  '                                        \t<td width="30" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DURYASBY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemF3-9Cnius6MoKw0GwZrayq5NRf7heyLJQzZd-mLv49Zq-V-Tu0CsKAr9YONXT0ev1upYJkRniHYGoEg9nWe255NGG15vt7tBBcQQYTmGuJSaVHnappU2y7Ri9DV3ePJ-JcOvMfPScNJwFzy."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_arrow_0717.gif" width="9" height="18" border="0" style="display:block;" /></a>',
#  '                                        \t</td>',
#  '                                      \t</tr>',
#  '                                    \t</table>',
#  '                                  \t</li>',
#  '                                  \t<li>',
#  '                                    \t<table border="0" cellpadding="0" cellspacing="0" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                      \t<tr>',
#  '                                        \t<td width="4" bgcolor="#ffffff" style="background-color:#ffffff;"></td>',
#  '                                        \t<td width="206" height="51" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURC&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemHrUxxdjqluo4mV6Jvx_YKcMcf15WsRUq9mig8rvrnXOIGkVBIjhQz4PR9J9Tn_HwijLFH7A3-g_khHk6ELHt4DQB4vXENJmMLX9cZCvulEqm8L7Rx5xpONYeuhC4L_-CEkrv7W80fjAaM." style="color:#393939; font-family:Arial, Helvetica, sans-serif; font-size:14px; line-height:51px; text-decoration:none; font-weight: bold; width: 100%; height: 100%; display: inline-block; vertical-align: middle; letter-spacing: .3px;">Sale</a>',
#  '                                        \t</td>',
#  '                                        \t<td width="30" align="left" valign="middle" bgcolor="#ffffff" style="background-color: #ffffff;">',
#  '                                          \t\t<a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBURC&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemHrUxxdjqluo4mV6Jvx_YKcMcf15WsRUq9mig8rvrnXOIGkVBIjhQz4PR9J9Tn_HwijLFH7A3-g_khHk6ELHt4DQB4vXENJmMLX9cZCvulEqm8L7Rx5xpONYeuhC4L_-CEkrv7W80fjAaM."><img src="https://static.cdn.responsys.net/i5/responsysimages/content/nordstrom/nav_arrow_0717.gif" width="9" height="18" border="0" style="display:block;" /></a>',
#  '                                        \t</td>',
#  '                                      \t</tr>',
#  '                                    \t</table>',
#  '                                  \t</li>',
#  '                                \t</ul>',
#  '                                \t<label for="navbar-checkbox" class="navbar-handle"></label>',
#  '                              \t</div>',
#  '                              \t<input type="hidden" name="__HIDDEN_FIELD_NAMES__" value="__HIDDEN_FIELD_NAMES__"><input',
#  ' type="hidden" name="__HIDDEN_FIELD_NAMES__" value="__HIDDEN_FIELD_NAMES__;__HIDDEN_FIELD_NAMES__">',
#  '                            \t</form>',
#  '                          \t</td>',
#  '                       \t</tr>',
#  '                        <tr>',
#  '                          \t<td height="30" style="height:30px;">&nbsp;</td>',
#  '                        </tr>',
#  '                      \t</table>',
#  '                    </div>',
#  '                \t<!--<![endif]-->',
#  '                <!-- /End HOLIDAY MOBILE NAV WITH HAMBURGER MENU -->',
#  '            </td>',
#  '        </tr>',
#  '        </table>',
#  '                    <!--/End Header Nav-->',
#  '                    ',
#  '                    <table cellpadding="0" cellspacing="0"><tr><td height="30"></td></tr></table>',
#  '',
#  '                    <!--start msg document-->',
#  '                    ',
#  '',
#  '<!-- Start Ship Confirm Message -->',
#  '<table cellpadding="0" cellspacing="0" width="598" class="width292 rel height55">',
#  '<tr>',
#  '    <td width="268" align="left" valign="top" class="abs width292 top0">',
#  '        <div style="padding-left:8px;" class="padl8">',
#  '              <img src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Msg_Prod.images/text_yourOrder2.png" width="268" height="24" alt="YOUR ORDER HAS" style="display:block;" />',
#  '        </div>',
#  '    </td>',
#  '    <td align="left" valign="top" class="abs width292 top30">',
#  '        <div class="paddingl8">',
#  '            <img src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Msg_Prod.images/text_shipped2.png" width="122" height="24" alt="SHIPPED" style="display:block;" />',
#  '        </div>',
#  '    </td>',
#  '</tr>',
#  '</table>',
#  '',
#  '<table cellpadding="0" cellspacing="0" width="598" class="width292">',
#  '<tr><td colspan="2" height="22"></td></tr>',
#  '<tr>',
#  '    <td width="10"></td>',
#  '    <td align="left" valign="top">',
#  '            <div style="font-family:Arial, Helvetica, sans-serif; font-size:16px; color:#5f5f5f; line-height:18px;">Good news, Crystal&#8212;your items are on their way!</div>',
#  '            ',
#  '            <table cellpadding="0" cellspacing="0"><tr><td height="14" style="line-height:14px;"><img src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Msg_Prod.images/spcr.gif" width="1" height="1" border="0" style="display:block;" /></td></tr></table>',
#  '            ',
#  '            <div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;">Here are a few things you should know:</div>',
#  '            ',
#  '            <table cellpadding="0" cellspacing="0">',
#  '            <tr><td colspan="2" height="6" style="line-height:6px;"><img src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Msg_Prod.images/spcr.gif" width="1" height="1" border="0" style="display:block;" /></td></tr>',
#  '            <tr>',
#  '                <td width="10" align="left" valign="top"><div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;">&bull;</div></td>',
#  '                <td align="left" valign="top"><div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;" class="lineheight16"><span class="block">Items may be shipped in separate boxes,</span> with no additional shipping charges.</div></td>',
#  '            </tr>',
#  '            <tr><td colspan="2" height="1" class="height2" style="line-height:1px;"><img src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Msg_Prod.images/spcr.gif" width="1" height="1" border="0" style="display:block;" /></td></tr>',
#  '            <tr>',
#  '                <td width="10" align="left" valign="top"><div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;">&bull;</div></td>',
#  '                <td align="left" valign="top"><div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;" class="lineheight16"><span class="block">If you have additional items in your order, we&rsquo;ll</span> send another confirmation once those ship.</div></td>',
#  '            </tr>',
#  '            <tr><td colspan="2" height="1" class="height2" style="line-height:1px;"><img src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Msg_Prod.images/spcr.gif" width="1" height="1" border="0" style="display:block;" /></td></tr>',
#  '            <tr>',
#  '                <td width="10" align="left" valign="top"><div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;">&bull;</div></td>',
#  '                <td align="left" valign="top"><div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;" class="lineheight16"><span class="block">Updated tracking information will be posted</span> to the carrier&rsquo;s website within 24 hours.</div></td>',
#  '            </tr>',
#  '            <tr>',
#  '                <td width="10" align="left" valign="top"><div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;">&bull;</div></td>',
#  '                <td align="left" valign="top"><div style="font-family:Arial, Helvetica, sans-serif; font-size:12px; color:#5f5f5f; line-height:18px;" class="lineheight16"><span class="block">If you have any problems with your order,</span> please <a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DCRTCDYY&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIpw4w2KZPenrSy8e7SwYemJhpKq2UoRsf6mfa04yQe-7LBa6laxRk_Etro4lN38KwM6ijbZhlrX_NETefJpwhfM13ySqdBNIECRJHjGVkPUsF37jG7ehr4nc8B0pIi588JEnBuugPkK2n-Myng6ywcV2EpvKAvWz5NLG0ihQ." style="color:#a42121; line-height:22px; text-decoration:underline;">contact us</a> within 30 days to resolve the issue.</div></td>',
#  '            </tr>',
#  '            <tr><td colspan="2" height="18" class="height19" style="line-height:18px;"><img src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Msg_Prod.images/spcr.gif" width="1" height="1" border="0" style="display:block;" /></td></tr>',
#  '            </table>',
#  '            ',
#  '            <!-- CTA -->',
#  '            <table cellpadding="0" cellspacing="0">',
#  '            <tr>',
#  '                <td height="25" align="center" bgcolor="#990000">',
#  '                    <div style="font-family:Arial, Helvetica, sans-serif; font-size:14px; color:#ffffff; line-height:16px; padding-left:15px; padding-right:15px;" class="pad15"><span class="block"><a href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DUURYBYY&_ei_=EmaIAlHppKvJM431BvlkNUyicWiVHwoC6BuvdV72hXEiUyDZ_akL7atGY8gReYGJjtaeE4PWS2-uH8fa8TXjWBAZOQIicDj9tvbPCKPdg9vZHPYK4Me0LcVY8R4Cv2DtERCTTzygWMncOKvVzXs90yv3GZuKIFoGJCC_CVogwcjYlz_JqlmQzQzdCpoiUdMk1WmorITdvulTNPAXdUiBguhpo0jC-_-exBkZaTb7fK57N6n5sQj1OcuIYW7uOx802NdGwShaiZp6k7MYNDeCsVx4c_vmPUipS3re_b61JeAN7bKFsOcUvWV4-r_fNvfj_GeOf2BAm5K68Ces9B2AA2lwHzcVEIQAPO9vyJJgcd2jd1ibJxhW_xYz0Z5WamKc7bP8PQ4Kzl_Vo-CXIeOYexU5oSzNRY5QEYQ1mdsVYPrRFaXnCCZ3xe6altwgz_DZNtiQ6OlquHaHHp68CDcAyrXktKD6qoOdEpJSyLU-UWHYpallw2OUB50XcIKltO0txxfDav6frtDwllILuzs5O6kCeKrIBBObqlkaG24zyi98CnNeWqTZs3_eqEWPHM." style="color:#ffffff; line-height:16px; text-decoration:none;">SEE EXPECTED DELIVERY DATE<img src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Msg_Prod.images/white_arrow.png" width="12" height="10" border="0" style="display:inline;" /></a></span></div>',
#  '                </td>',
#  '            </tr>',
#  '            </table>',
#  '            <!-- CTA -->',
#  '<script type="application/ld+json">',
#  '{',
#  '  "@context": "http://schema.org",',
#  '  "@type": "EmailMessage",',
#  '  "potentialAction": {',
#  '    "@type": "ViewAction",',
#  '    "target": "https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DUURYBYY&_ei_=EmaIAlHppKvJM431BvlkNUyicWiVHwoC6BuvdV72hXEiUyDZ_akL7atGY8gReYGJjtaeE4PWS2-uH8fa8TXjWBAZOQIicDj9tvbPCKPdg9vZHPYK4Me0LcVY8R4Cv2DtERCTTzygWMncOKvVzXs90yv3GZuKIFoGJCC_CVogwcjYlz_JqlmQzQzdCpoiUdMk1WmorITdvulTNPAXdUiBguhpo0jC-_-exBkZaTb7fK57N6n5sQj1OcuIYW7uOx802NdGwShaiZp6k7MYNDeCsVx4c_vmPUipS3re_b61JeAN7bKFsOcUvWV4-r_fNvfj_GeOf2BAm5K68Ces9B2AA2lwHzcVEIQAPO9vyJJgcd2jd1ibJxhW_xYz0Z5WamKc7bP8PQ4Kzl_Vo-CXIeOYexU5oSzNRY5QEYQ1mdsVYPrRFaXnCCZ3xe6altwgz_DZNtiQ6OlquHaHHp68CDcAyrXktKD6qoOdEpJSyLU-UWHYpallw2OUB50XcIKltO0txxfDav6frtDwllILuzs5O6kCeKrIBBObqlkaG24zyi98CnNeWqTZs3_eqEWPHM.",',
#  '    "name": "Track Package"',
#  '  }',
#  '}',
#  '</script>',
#  '            ',
# ...
#  '</div>',
#  '<div style="line-height:16px; color:#000001;">#5275249</div>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:9px;" class="height12" height="9"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '<table class="floatleft width74" width="1" cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width66 height101 floatleft" height="0" width="1" valign="top" align="left">',
#  '                                            ',
#  '                                            ',
#  '                                            <!--[if !mso]><!-->',
#  '                                            <div style="display:none; float:left; overflow:hidden; width:0; max-height:0; line-height:0;" class="showme">',
#  '<a target="_blank" href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBUSU&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIrqVcaTEia5Y59lFH7Xra6fZQ4aO2tfWSa8KouWVCJas69kv2PQOKarGwk7rVIVD2mXCUSL0ROU_uCrIMDCcGrlBkD96RwkglCBBhuxM-VFbUXuj7YMz-BMCRXihMG4AB9Ka07GdmWdz4RNh0-xfcF1VWrtCxVFse_JEAInMtQ-Xi1pq3n0B2NkwKZwcVyO_5Dod6C8FbadBm4tw3BUgy1PTJNdoT5N1VdYFC."><img class="width66 hauto" style="display:block; border:0;" height="0" width="1" src="https://n.nordstrommedia.com/imagegallery/store/product/Medium/4/_100019384.jpg"></a>',
#  '</div>',
#  '                                            <!--<![endif]-->',
#  '                                            ',
#  '                                        </td>',
#  '</tr>',
#  '</table>',
#  '<div class="floatleft width206">',
#  '<table class="width206" cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<th style="font-weight:normal;" class="block width206" valign="top" align="left" width="79">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left" width="79">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                              Qty:<br class="hide">',
#  '<span style="color:#010101;">1</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th><th style="font-weight:normal;" class="block width206" valign="top" align="left" width="110">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left" width="110">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                              Color:<br class="hide">',
#  '<span style="color:#010101;">No Color</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th><th style="font-weight:normal;" class="block width206" valign="top" align="left" width="91">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left" width="91">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                                  Size:<br class="hide">',
#  '<span style="color:#010101;">One Size</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th><th style="font-weight:normal;" class="block width206" valign="top" align="left" width="121">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left" width="121">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                              Status:<br class="hide">',
#  '<span style="color:#010101;">Shipped</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th><th style="font-weight:normal;" class="block width206" valign="top" align="left">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                              Price:<br class="hide">',
#  '<span style="color:#010101;">$0.00</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th>',
#  '</tr>',
#  '</table>',
#  '</div>',
#  '</td>',
#  '</tr>',
#  '<tr>',
#  '<td height="20" colspan="3"></td>',
#  '</tr>',
#  '</table><table class="width292" width="598" cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width10" width="9"></td><td class="hide" valign="top" align="left" height="135" width="103"><a target="_blank" href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBUUA&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIrqVcaTEia5Y59lFH7Xra6fZQ4aO2tfWSa8KouWVCJas69kv2PQOKarGwk7rVIVD2t9wEpaoYr_nXI579nKsOm3KqUt6AlouVJWZAbv3exUvhhAQ4LvMBttfC2LjWEx2SjIlEljZ8G8rz1XO1G0w87eonh8_uknp3p1O1iZJM_V8IzOsVF2I29Q96xbdA-bu3niFyNfGk8269lsTGt-RQ3bUYufXxywWHIcmG."><img class="hide" style="display:block; border:0;" width="88" src="https://n.nordstrommedia.com/imagegallery/store/product/Medium/17/_101155177.jpg"></a></td><td class="block width282" valign="middle" align="left" width="486">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px;">',
#  '<div style="font-weight:bold; line-height:16px; color:#646464;">Description:</div>',
#  '<div style="line-height:16px; color:#646464;">',
#  '<a style="color:#990000; text-decoration:underline;" href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBUUB&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIrqVcaTEia5Y59lFH7Xra6fZQ4aO2tfWSa8KouWVCJas69kv2PQOKarGwk7rVIVD2t9wEpaoYr_nXI579nKsOm6wYt9AwrAJ-a2aEKM4hRWk3fV9L2GZAi2ttscqKSbTXWy9x1aY7qfDCc0QtmhY4SePRoJR27cxvQHM8GWLbEa0EgyLWMfFR0zs-PQcRTX8ZxpTTQBunT9svzDm8e7qODTmoIU_ZAxEF0A4."><span>Lanc&ocirc;me Gift with Purchase</span></a>',
#  '</div>',
#  '<div style="line-height:16px; color:#000001;">#5366199</div>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:9px;" class="height12" height="9"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '<table class="floatleft width74" width="1" cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width66 height101 floatleft" height="0" width="1" valign="top" align="left">',
#  '                                            ',
#  '                                            ',
#  '                                            <!--[if !mso]><!-->',
#  '                                            <div style="display:none; float:left; overflow:hidden; width:0; max-height:0; line-height:0;" class="showme">',
#  '<a target="_blank" href="https://em.nordstrom.com/pub/cc?_ri_=X0Gzc2X%3DYQpglLjHJlYQGj8PPNsLS2za33wf51Iun134zfoWCamUTN9o9fMJDLTvFdyK3azeRVXtpKX%3DWSBUUA&_ei_=EmaIAlHppKvJM431BvlkNUwz2ZnrBv1BXqrYmA8MGIWIrqVcaTEia5Y59lFH7Xra6fZQ4aO2tfWSa8KouWVCJas69kv2PQOKarGwk7rVIVD2t9wEpaoYr_nXI579nKsOm3KqUt6AlouVJWZAbv3exUvhhAQ4LvMBttfC2LjWEx2SjIlEljZ8G8rz1XO1G0w87eonh8_uknp3p1O1iZJM_V8IzOsVF2I29Q96xbdA-bu3niFyNfGk8269lsTGt-RQ3bUYufXxywWHIcmG."><img class="width66 hauto" style="display:block; border:0;" height="0" width="1" src="https://n.nordstrommedia.com/imagegallery/store/product/Medium/17/_101155177.jpg"></a>',
#  '</div>',
#  '                                            <!--<![endif]-->',
#  '                                            ',
#  '                                        </td>',
#  '</tr>',
#  '</table>',
#  '<div class="floatleft width206">',
#  '<table class="width206" cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<th style="font-weight:normal;" class="block width206" valign="top" align="left" width="79">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left" width="79">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                              Qty:<br class="hide">',
#  '<span style="color:#010101;">1</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th><th style="font-weight:normal;" class="block width206" valign="top" align="left" width="110">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left" width="110">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                              Color:<br class="hide">',
#  '<span style="color:#010101;">No Color</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th><th style="font-weight:normal;" class="block width206" valign="top" align="left" width="91">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left" width="91">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                                  Size:<br class="hide">',
#  '<span style="color:#010101;">One Size</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th><th style="font-weight:normal;" class="block width206" valign="top" align="left" width="121">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left" width="121">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                              Status:<br class="hide">',
#  '<span style="color:#010101;">Shipped</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th><th style="font-weight:normal;" class="block width206" valign="top" align="left">',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td class="width206" valign="top" align="left">',
#  '<div style="font-family: Arial, Helvetica, sans-serif; font-size:12px; color:#646464; line-height:16px;">',
#  '                                              Price:<br class="hide">',
#  '<span style="color:#010101;">$0.00</span>',
#  '</div>',
#  '<table cellspacing="0" cellpadding="0">',
#  '<tr>',
#  '<td style="line-height:5px;" height="5"><img style="display:block;" border="0" height="1" width="1" src="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_XSL_DetailsNow_prod.images/spcr.gif"></td>',
#  '</tr>',
#  '</table>',
#  '</td>',
#  '</tr>',
#  '</table>',
#  '</th>',
#  '</tr>',
#  '</table>',
#  '</div>',
#  '</td>',
#  '</tr>',
#  '<tr>',
#  '<td height="20" colspan="3"></td>',
#  '</tr>',
#  '</table>',
#  '',
#  '                     ',
#  '',
#  '                     <!-- End XSLT Order Details -->',
#  '                    ',
#  '                  </td>',
#  '         </tr>',
#  '         </table>',
#  '         ',
#  '         <table cellpadding="0" cellspacing="0"><tr><td height="20"></td></tr></table>',
#  '                        ',
#  '          <!-- XSLT Billing Doc -->',
#  '          ',
#  '<!-- Start Bill Summary Headline -->',
#  '<table cellpadding="0" cellspacing="0" width="598" class="width292">',
#  '<tr><td align="left" width="598" height="25" class="width292" background="https://static.cdn.responsys.net/i5/responsysimages/nordstrom/contentlibrary/oldcontent/_Transactional_ConfirmOrderShipment_400_Prod/_Transactional_ConfirmOrderShipment_400_Billing_Prod.images/gray_tile1x25.gif" bgcolor="#d1cdca">',
#  '      <!--[if gte mso 9]>',
#  '      <v:rect xmlns:v="urn:schemas-microsoft-com:vml" fill="true" stroke="false" style="width:598px;height:25px;">',
#  ...]
